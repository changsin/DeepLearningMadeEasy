# %% [markdown]
# <a href="https://colab.research.google.com/github/changsin/DeepLearningMadeEasy/blob/main/flag_classification/Problem-Definition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Flag Classification Project
#
# The best way to learn a subject is by doing it yourself. For this purpose, Please write a project proposal to build an AI system to classify country flags. The project definition is intentional left as very vague so that you can ask questions and find your answers. You are welcome to discuss in the forum and other classmates, but each person is to come up with a notebook for his or her answer and share it with the rest of the class.

# %% [markdown]
# Here is the basic idea. If the image of a flag is presented

# %% [markdown]
# ![tz.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# the AI system answers "Tanzania".

# %% [markdown]
# ## 1. Define inputs and outputs

# %% [markdown]
# ## 2. How and where would you collect the input data?

# %% [markdown]
# ## 3. What does "labeling" mean? How would you label the data?
